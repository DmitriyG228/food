# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0,'..')

# %%
from mytools.tools import *

from food.paths import *
from food.psql import *

import pandas as pd
import numpy as np

# !nbdev_build_lib
from pathlib import Path

from mytools.visual import get_text_clip,search_clip,series2tensor

# %%
data_path = Path('../food_dataset')

# %%
input_food = (pd.read_csv(data_path/'input_food.csv').set_index('fdc_id')[['gram_weight','sr_description']]
              .rename(columns = {'sr_description':'input','gram_weight':'input_weight'})
              .sort_values('input_weight'))

# %%
food = pd.read_csv(data_path/'food.csv')

# %%
food = food[food['data_type']=='survey_fndds_food'].set_index('fdc_id')[['description']]

# %%
food = food.join(input_food)

# %%
food = food[~food['input'].isin(['Beverages, water, tap, drinking',
                                 'Salt, table, iodized'])]

# %%
def func(g):
    g = g.sort_values('input_weight')
    g['cumsum'] = g['input_weight'].cumsum()/g['input_weight'].sum()
    g = g.sort_values('cumsum',ascending = False)
    
    g = g[g['cumsum']>0.05]
    return g

# %%
food = food.groupby('fdc_id').apply(func)

# %%
food = food.sort_values('input_weight',ascending = False)

# %%
food.index = [i[1] for i in food.index]

# %%
f = food.reset_index().groupby('index').agg({'description':'first','input':lambda l:'; '.join(l)})

# %%
df = f.apply(lambda ff:f'"{ff["description"]}" made of {ff["input"]}',axis=1)

# %%
df = df.reset_index(name='text').rename(columns = {'index':'food_id'})

# %%
df
# Out:
#       food_id                                               text
# 0     1097510   "Milk, human" made of Milk, human, mature, fluid
# 1     1097511  "Milk, NFS" made of Milk, reduced fat, fluid, ...
# 2     1097512  "Milk, whole" made of Milk, whole, 3.25% milkf...
# 3     1097513  "Milk, low sodium, whole" made of Milk, low so...
# 4     1097514  "Milk, calcium fortified, whole" made of Milk,...
# ...       ...                                                ...
# 7077  1104588  "Tomatoes as ingredient in omelet" made of Tom...
# 7078  1104589  "Other vegetables as ingredient in omelet" mad...
# 7079  1104590  "Vegetables as ingredient in curry" made of On...
# 7080  1104591  "Sauce as ingredient in hamburgers" made of Ca...
# 7081  1104592  "Industrial oil as ingredient in food" made of...
#
# [7082 rows x 2 columns]

# %%
df['version'] = 2

# %%
df.to_sql('foods_prompted',engine,if_exists = 'append',index = False,schema = 'food')
# Out:
# 82

# %%
pd.read_sql('select * from food.foods_prompted',engine)
# Out:
#          id  food_id                                               text  \
# 0      1867  1099376   the photo of "Meat loaf made with chicken or ...
# 1      1868  1099377   the photo of "Clams, stuffed" dish, which is ...
# 2      1869  1099378   the photo of "Codfish ball or cake" dish, whi...
# 3      1870  1099379   the photo of "Crab cake" dish, which is made ...
# 4      1871  1099380   the photo of "Fish cake or patty, NS as to fi...
# ...     ...      ...                                                ...
# 14159  7078  1104588   the photo of "Tomatoes as ingredient in omele...
# 14160  7079  1104589   the photo of "Other vegetables as ingredient ...
# 14161  7080  1104590   the photo of "Vegetables as ingredient in cur...
# 14162  7081  1104591   the photo of "Sauce as ingredient in hamburge...
# 14163  7082  1104592   the photo of "Industrial oil as ingredient in...
#
#        version                                               clip
# 0            1  [-0.009547241, 0.027974756, -0.0008684345, 0.0...
# 1            1  [0.034463722, 0.006951217, -0.030041857, 0.020...
# 2            1  [0.009532085, 0.012929418, 0.033163667, 0.0550...
# 3            1  [-0.0019750579, 0.011804303, -0.019615391, 0.0...
# 4            1  [0.0056863017, 0.0066959057, 0.015637038, 0.03...
# ...        ...                                                ...
# 14159        1  [0.07593674, 0.023695257, 0.014061779, 0.03602...
# 14160        1  [0.07699164, 0.014432207, 0.022694767, 0.04846...
# 14161        1  [0.0098340195, 0.00041265108, 0.0053099045, 0....
# 14162        1  [0.019054852, 0.027971897, 0.029259693, -0.009...
# 14163        1  [-0.00057650096, 0.043657582, 0.02375392, 0.05...
#
# [14164 rows x 5 columns]

# %%
q = """select p.clip, p.text, p.version,f.description,f.category 
       from food.foods_prompted as p
       join food.foods as f on (p.food_id = f.id)
       where p.clip is not null
       """

# %%
foods = pd.read_sql(q,engine)

# %%
foods_old = pd.read_sql('select * from food.foods where clip is not null',engine)

# %%
foods
# Out:
#                                                    clip  \
# 0     [-0.009547241, 0.027974756, -0.0008684345, 0.0...
# 1     [0.034463722, 0.006951217, -0.030041857, 0.020...
# 2     [0.009532085, 0.012929418, 0.033163667, 0.0550...
# 3     [-0.0019750579, 0.011804303, -0.019615391, 0.0...
# 4     [0.0056863017, 0.0066959057, 0.015637038, 0.03...
# ...                                                 ...
# 9093  [0.029202031, 0.0440451, -0.008807819, 0.04436...
# 9094  [0.030916419, 0.040611614, -0.009172419, 0.048...
# 9095  [0.017849905, 0.052032243, -0.011163072, 0.035...
# 9096  [0.027764209, 0.048447695, -0.007417399, 0.044...
# 9097  [0.029273704, 0.039951853, -0.0060664094, 0.03...
#
#                                                    text  version  \
# 0      the photo of "Meat loaf made with chicken or ...        1
# 1      the photo of "Clams, stuffed" dish, which is ...        1
# 2      the photo of "Codfish ball or cake" dish, whi...        1
# 3      the photo of "Crab cake" dish, which is made ...        1
# 4      the photo of "Fish cake or patty, NS as to fi...        1
# ...                                                 ...      ...
# 9093  "Chicken or turkey, potatoes, and vegetables i...        2
# 9094  "Chicken or turkey, potatoes, and vegetables e...        2
# 9095  "Chicken or turkey, potatoes, and vegetables i...        2
# 9096  "Chicken or turkey, potatoes, and vegetables e...        2
# 9097  "Chicken or turkey, potatoes, and vegetables i...        2
#
#                                             description
# 0     Meat loaf made with chicken or turkey, with to...
# 1                                        Clams, stuffed
# 2                                  Codfish ball or cake
# 3                                             Crab cake
# 4                     Fish cake or patty, NS as to fish
# ...                                                 ...
# 9093  Chicken or turkey, potatoes, and vegetables in...
# 9094  Chicken or turkey, potatoes, and vegetables ex...
# 9095  Chicken or turkey, potatoes, and vegetables in...
# 9096  Chicken or turkey, potatoes, and vegetables ex...
# 9097  Chicken or turkey, potatoes, and vegetables in...
#
# [9098 rows x 4 columns]

# %%
food_clips = series2tensor(foods['clip'])

# %%
food_clips_old = series2tensor(foods_old['clip'])

# %%
url = 'https://img-global.cpcdn.com/recipes/2e5de88897d95c0c/400x400cq70/photo.jpg'

# %%
r = search_clip(url,foods,food_clips)[1];r
# Out:
#    index                                               clip  \
# 0   4148  [0.0111375665, 0.032855168, 0.016608622, 0.034...
#
#                                                 text  version  \
# 0   the photo of "Barley, fat added" dish, which ...        1
#
#          description     score
# 0  Barley, fat added  0.311238

# %%
r['text'].iloc[0]
# Out:
# ' the photo of "Barley, fat added" dish, which is made of the following: Barley, pearled, cooked'

# %%
search_clip(url,foods_old,food_clips_old)[1]
# Out:
#    index       id                     description  \
# 0   4047  1101537  Buckwheat groats, no added fat
#
#                         category  energy  protein   carb   fat  \
# 0  Pasta, noodles, cooked grains    92.0     3.37  19.86  0.62
#
#                                                 clip     score
# 0  [0.031248957, 0.014652966, 0.029392239, 0.0195...  0.272619

# %%
search_clip
# Out:
# <function food.tools.search_clip(url, foods, food_clips, head=1)>

# %%
engine.execute("drop table food.foods_prompted")
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# UndefinedTable: table "foods_prompted" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 engine.execute("drop table food.foods_prompted")
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/anaconda3/envs/f4/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) table "foods_prompted" does not exist
#
# [SQL: drop table food.foods_prompted]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
df
# Out:
#       food_id                                               text  version
# 0     1097510   the photo of "Milk, human" dish, which is mad...        1
# 1     1097511   the photo of "Milk, NFS" dish, which is made ...        1
# 2     1097512   the photo of "Milk, whole" dish, which is mad...        1
# 3     1097513   the photo of "Milk, low sodium, whole" dish, ...        1
# 4     1097514   the photo of "Milk, calcium fortified, whole"...        1
# ...       ...                                                ...      ...
# 7077  1104588   the photo of "Tomatoes as ingredient in omele...        1
# 7078  1104589   the photo of "Other vegetables as ingredient ...        1
# 7079  1104590   the photo of "Vegetables as ingredient in cur...        1
# 7080  1104591   the photo of "Sauce as ingredient in hamburge...        1
# 7081  1104592   the photo of "Industrial oil as ingredient in...        1
#
# [7082 rows x 3 columns]

# %%
get_text_clip('dogs')
# Out:
# tensor([ 1.6915e-02,  1.2465e-02,  8.9097e-03, -2.9618e-02,  1.7291e-02,
#          1.7569e-03,  1.9857e-02,  8.7645e-03, -9.6193e-03, -3.8230e-02,
#         -1.6027e-02, -1.1519e-02,  1.5489e-02,  1.2435e-02, -1.1473e-02,
#          9.1915e-03, -4.4956e-03,  1.3724e-02, -1.2408e-02,  8.3505e-03,
#         -2.4924e-02, -1.0489e-02,  1.8021e-02,  9.3614e-04,  1.5869e-02,
#          8.7736e-04, -2.8382e-03, -1.2125e-02, -4.0839e-03,  1.0921e-03,
#         -2.2746e-02,  8.6543e-03, -1.8522e-02, -4.0211e-02, -1.6811e-02,
#         -7.1129e-03, -1.7050e-02, -1.8504e-03, -2.1892e-02,  5.4940e-03,
#          1.2249e-02,  8.0643e-03, -5.4576e-03, -2.4247e-03,  8.2767e-03,
#         -9.8407e-03,  1.0315e-03,  1.2344e-02,  1.1869e-02, -1.3152e-02,
#         -3.3823e-03,  1.6768e-03,  2.2077e-02,  2.5708e-02, -1.2388e-02,
#          1.6520e-02, -1.7282e-03,  1.7294e-02, -6.7715e-03,  5.1089e-03,
#          1.1791e-03,  1.3683e-02,  3.0604e-02, -2.8036e-02, -7.3349e-03,
#          7.9450e-03, -4.9110e-03,  2.2022e-03,  1.3985e-02, -3.5134e-03,
#         -1.1064e-02,  2.5866e-02, -2.6301e-02,  7.8758e-04, -1.3962e-03,
#          1.0881e-02,  7.6455e-03, -9.7432e-04, -1.3582e-02, -2.3458e-02,
#          1.6416e-02, -1.8431e-02, -6.4556e-03,  1.6292e-02, -2.1974e-02,
