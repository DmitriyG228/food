# %%
from food.tools import *
from food.paths import *
from food.psql import *
import numpy as np
import torch
from torch.nn import CosineSimilarity
import requests
from food.qdrant import *
cos = CosineSimilarity(dim=1, eps=1e-08)
import pandas as pd

# %%
#export
def search_image(url=None,head = 1):
    image_clip = requests.post(f'https://guru.skynet.center/image2vector/?url={url}').json()
    results = client.search(collection_name=collection_name,query_vector=image_clip,top=head)
    image_clip = torch.Tensor(image_clip)
    df = foods.loc[[r.id for r in results]].copy()
    df['score'] = [r.score for r in results]
    df = df.sort_values('score',ascending=False)

    return image_clip,df.reset_index()

series2tensor = lambda series:torch.tensor([np.array(c) for c in series.values])

# %%
collection_name = 'food'
table = 'foods'
foods = read_sql(table)
# foods = foods.drop(columns = ['clip'])
foods = foods.set_index('id')

# %%
url = 'http://glovo.away.guru/photos_resized/NZTCKFL_0076494_1516096262.png'
image_clip,df = search_image(url,head=100)

# %%
selected = df.copy()

# %%
selected = selected.reset_index(drop=True)
clip = series2tensor(selected['clip'])
initscore = cos(image_clip.reshape(1,768), clip.mean(0).reshape(1,768))
# Out:
# /tmp/ipykernel_1849641/588996549.py:12: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /opt/conda/conda-bld/pytorch_1640811803361/work/torch/csrc/utils/tensor_new.cpp:201.)
#   series2tensor = lambda series:torch.tensor([np.array(c) for c in series.values])

# %%
selected = selected.reset_index(drop=True)
for i in reversed(selected.index):
    clip = series2tensor(selected['clip'])
    T = torch.cat([clip[0:i], clip[i+1:]])
    testscore = cos(image_clip.reshape(1,768), T.mean(0).reshape(1,768))
    if testscore > initscore: 
        r = selected.loc[i,'description']
        selected = selected.drop(i)
        initscore = testscore
        # print(f"removed {r}")
    else:
        T = torch.cat([clip, clip[i].reshape(1,768)])
        testscore = cos(image_clip.reshape(1,768), T.mean(0).reshape(1,768))
        if testscore > initscore: 
            selected = selected.append(selected.loc[i])
            # print(f"added {selected.loc[i,'description']}")
            initscore = testscore

    



print(initscore)
count = selected.groupby('description')['clip'].count().sort_index()
r = selected.drop_duplicates('description').set_index("description").sort_index()
r['count'] = count
r.sort_values('count',ascending = False)
# Out:
# tensor([0.2846], dtype=torch.float64)
#                                                          id  \
# description
# Apple juice, 100%, with calcium added               1102748
# Nutrition bar (Balance Original Bar)                1101259
# Muffin, English, with fruit other than raisins      1100732
# Kohlrabi, raw                                       1103356
# Halvah, plain                                       1104068
# Pie, apple, individual size or tart                 1101062
# Gin                                                 1104487
# Fritter, apple                                      1101153
# Apple, baked                                        1102649
# Crepe, plain                                        1101513
# Cobbler, pear                                       1101149
# Cobbler, apple                                      1101144
# Cabbage, red, raw                                   1103343
# Pimiento                                            1103564
# Apples, baby food, toddler                          1102782
# Apples with ham, baby food, strained                1102877
# Turnover or dumpling, apple                         1101181
# Apple, raw                                          1102644
# Apple, dried                                        1102624
# Wheat germ, plain                                   1101819
# Nectarine, raw                                      1102673
# Shortening, NS as to vegetable or animal            1103843
# Dutch apple dessert, baby food, junior              1102867
# Guava, raw                                          1102666
# Big Mac (McDonalds)                                 1099788
# Apple-raspberry, baby food, junior                  1102785
# Apple-raspberry, baby food, NS as to strained o...  1102783
# Apple, candied                                      1102721
# Whole wheat cereal with apples, baby food, dry,...  1101839
#
#                                                                              category  \
# description
# Apple juice, 100%, with calcium added                                     Apple juice
# Nutrition bar (Balance Original Bar)                                   Nutrition bars
# Muffin, English, with fruit other than raisins             Bagels and English muffins
# Kohlrabi, raw                                       Other vegetables and combinations
# Halvah, plain                                          Candy not containing chocolate
# Pie, apple, individual size or tart                                    Cakes and pies
# Gin                                                              Liquor and cocktails
# Fritter, apple                                       Doughnuts, sweet rolls, pastries
# Apple, baked                                                                   Apples
# Crepe, plain                                          Pancakes, waffles, French toast
# Cobbler, pear                                                          Cakes and pies
# Cobbler, apple                                                         Cakes and pies
# Cabbage, red, raw                                                             Cabbage
# Pimiento                                                 Mustard and other condiments
# Apples, baby food, toddler                                           Baby food: fruit
# Apples with ham, baby food, strained                      Baby food: meat and dinners
# Turnover or dumpling, apple                                            Cakes and pies
# Apple, raw                                                                     Apples
# Apple, dried                                                             Dried fruits
# Wheat germ, plain                                     Not included in a food category
# Nectarine, raw                                                 Peaches and nectarines
# Shortening, NS as to vegetable or animal                                    Margarine
# Dutch apple dessert, baby food, junior                   Baby food: snacks and sweets
# Guava, raw                                              Other fruits and fruit salads
# Big Mac (McDonalds)                                             Burgers (single code)
# Apple-raspberry, baby food, junior                                   Baby food: fruit
# Apple-raspberry, baby food, NS as to strained o...                   Baby food: fruit
# Apple, candied                                                                 Apples
# Whole wheat cereal with apples, baby food, dry,...                 Baby food: cereals
#
#                                                     energy  protein   carb  \
# description
# Apple juice, 100%, with calcium added                 48.0     0.12  11.49
# Nutrition bar (Balance Original Bar)                 415.0    28.00  48.73
# Muffin, English, with fruit other than raisins       243.0     9.31  47.63
# Kohlrabi, raw                                         27.0     1.70   6.20
# Halvah, plain                                        521.0     7.98  57.36
# Pie, apple, individual size or tart                  316.0     3.00  42.60
# Gin                                                  231.0     0.00   0.00
# Fritter, apple                                       381.0     6.46  34.75
# Apple, baked                                         112.0     0.32  22.70
# Crepe, plain                                         223.0     8.78  21.73
# Cobbler, pear                                        215.0     2.15  42.06
# Cobbler, apple                                       194.0     2.31  36.38
# Cabbage, red, raw                                     31.0     1.43   7.37
# Pimiento                                              28.0     1.35   6.24
# Apples, baby food, toddler                            50.0     0.19  11.56
# Apples with ham, baby food, strained                  62.0     2.60  10.90
# Turnover or dumpling, apple                          348.0     3.64  43.55
# Apple, raw                                            52.0     0.26  13.81
# Apple, dried                                         243.0     0.93  65.89
# Wheat germ, plain                                    382.0    29.10  49.60
# Nectarine, raw                                        39.0     1.06   9.18
# Shortening, NS as to vegetable or animal             884.0     0.00   0.00
# Dutch apple dessert, baby food, junior                79.0     0.20  19.18
# Guava, raw                                            68.0     2.55  14.32
# Big Mac (McDonalds)                                  261.0    11.94  21.53
# Apple-raspberry, baby food, junior                    60.0     0.20  16.00
# Apple-raspberry, baby food, NS as to strained o...    60.0     0.20  15.98
# Apple, candied                                       134.0     1.34  29.61
# Whole wheat cereal with apples, baby food, dry,...   402.0     6.60  83.20
#
#                                                       fat  \
# description
# Apple juice, 100%, with calcium added                0.17
# Nutrition bar (Balance Original Bar)                12.00
# Muffin, English, with fruit other than raisins       1.80
# Kohlrabi, raw                                        0.10
# Halvah, plain                                       32.04
# Pie, apple, individual size or tart                 16.10
# Gin                                                  0.00
# Fritter, apple                                      24.46
# Apple, baked                                         3.04
# Crepe, plain                                        10.93
# Cobbler, pear                                        4.93
# Cobbler, apple                                       4.95
# Cabbage, red, raw                                    0.16
# Pimiento                                             0.37
# Apples, baby food, toddler                           0.36
# Apples with ham, baby food, strained                 0.90
# Turnover or dumpling, apple                         18.08
# Apple, raw                                           0.17
# Apple, dried                                         0.32
# Wheat germ, plain                                   10.70
# Nectarine, raw                                       0.28
# Shortening, NS as to vegetable or animal            99.97
# Dutch apple dessert, baby food, junior               0.16
# Guava, raw                                           0.95
# Big Mac (McDonalds)                                 14.10
# Apple-raspberry, baby food, junior                   0.20
# Apple-raspberry, baby food, NS as to strained o...   0.20
# Apple, candied                                       2.15
# Whole wheat cereal with apples, baby food, dry,...   4.80
#
#                                                                                                  clip  \
# description
# Apple juice, 100%, with calcium added               [0.01414635, 0.006959528, 0.0035419979, 0.0569...
# Nutrition bar (Balance Original Bar)                [-0.01209534, 0.0036753116, 0.058078367, -0.00...
# Muffin, English, with fruit other than raisins      [-0.018083451, -0.0061937105, 0.050549187, 0.0...
# Kohlrabi, raw                                       [0.046535134, -0.025247127, -0.0028286164, -0....
# Halvah, plain                                       [0.015021525, 0.045297496, 0.011053128, 0.0089...
# Pie, apple, individual size or tart                 [0.038439795, 0.007134675, 0.031249179, 0.0065...
# Gin                                                 [0.0077090804, -0.0048638433, 0.041360896, -0....
# Fritter, apple                                      [0.057608202, 0.031312082, 0.02672885, -0.0110...
# Apple, baked                                        [0.02772038, -0.01954301, 0.027409052, -0.0049...
# Crepe, plain                                        [0.07472039, 0.041357704, -0.0068391925, -0.01...
# Cobbler, pear                                       [0.05414921, -0.031237641, 0.026125355, -0.021...
# Cobbler, apple                                      [0.03982123, -0.021529237, 0.030978544, -0.001...
# Cabbage, red, raw                                   [0.067335136, 0.014064836, -0.0027001977, -0.0...
# Pimiento                                            [0.04465482, 0.015551894, 0.030614525, -0.0215...
# Apples, baby food, toddler                          [0.0003478544, -0.022820584, 0.033641424, 0.00...
# Apples with ham, baby food, strained                [0.040114325, 0.0004856281, 0.026920851, 0.002...
# Turnover or dumpling, apple                         [0.047357026, 0.0405507, -0.015996952, -0.0136...
# Apple, raw                                          [0.03289434, 0.009451146, 0.04302109, -0.00526...
# Apple, dried                                        [0.028333109, 0.02973773, 0.024424564, 0.00799...
# Wheat germ, plain                                   [0.039400585, 0.046563674, 0.016098605, 0.0004...
# Nectarine, raw                                      [0.03962149, 0.015953789, 0.0055913106, -0.034...
# Shortening, NS as to vegetable or animal            [0.012704794, 0.0495215, 0.027456267, 0.011062...
# Dutch apple dessert, baby food, junior              [0.0120423, -0.009328228, 0.005196075, 0.01825...
# Guava, raw                                          [0.040717945, 0.0040670736, 0.001589361, -0.04...
# Big Mac (McDonalds)                                 [0.046593145, 0.00064619037, 0.054684907, 0.01...
# Apple-raspberry, baby food, junior                  [0.017580543, -0.0077860574, 0.03652114, 0.011...
# Apple-raspberry, baby food, NS as to strained o...  [0.010356599, 0.027557164, 0.041498747, 0.0288...
# Apple, candied                                      [0.055646118, 0.04152919, 0.0068586967, 0.0163...
# Whole wheat cereal with apples, baby food, dry,...  [0.017155621, 0.015462028, 0.0072350083, 0.017...
#
#                                                        score  count
# description
# Apple juice, 100%, with calcium added               0.230542      2
# Nutrition bar (Balance Original Bar)                0.202616      2
# Muffin, English, with fruit other than raisins      0.206761      2
# Kohlrabi, raw                                       0.205997      2
# Halvah, plain                                       0.208304      2
# Pie, apple, individual size or tart                 0.232672      2
# Gin                                                 0.199616      2
# Fritter, apple                                      0.258467      2
# Apple, baked                                        0.255700      2
# Crepe, plain                                        0.219865      2
# Cobbler, pear                                       0.207675      2
# Cobbler, apple                                      0.239396      2
# Cabbage, red, raw                                   0.199914      2
# Pimiento                                            0.201734      2
# Apples, baby food, toddler                          0.245114      2
# Apples with ham, baby food, strained                0.208555      2
# Turnover or dumpling, apple                         0.246986      2
# Apple, raw                                          0.274602      2
# Apple, dried                                        0.243466      2
# Wheat germ, plain                                   0.203743      2
# Nectarine, raw                                      0.230622      2
# Shortening, NS as to vegetable or animal            0.207074      1
# Dutch apple dessert, baby food, junior              0.209188      1
# Guava, raw                                          0.210680      1
# Big Mac (McDonalds)                                 0.202096      1
# Apple-raspberry, baby food, junior                  0.229503      1
# Apple-raspberry, baby food, NS as to strained o...  0.239178      1
# Apple, candied                                      0.240039      1
# Whole wheat cereal with apples, baby food, dry,...  0.214636      1

# %%
read_image_from_url(url)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F263080C430>

# %% [markdown]
# use prompts sand alterations to dish names

# %%
url = 'http://glovo.away.guru/photos_resized/NZTCKFL_0076494_1516096262.png'

# %%
# url = 'https://image.shutterstock.com/image-photo/smorrebrod-traditional-danish-sandwiches-long-600w-1907860309.jpg'
image_clip,df = search_image(url,head=100)

# %%
selected = df.copy()

# %%
selected['altered_description'] = 'I am going to eat some ' +selected['description'].str.split(',').apply(lambda l:' '.join(list(reversed(l)))) + ' which blongs to ' + selected['category'] #selected['category']#+' '+selected['description'].str.replace(',','') I am going to eat some

# %%
selected
# Out:
#          id                                        description  \
# 0   1102644                                         Apple, raw
# 1   1101153                                     Fritter, apple
# 2   1102649                                       Apple, baked
# 3   1101181                        Turnover or dumpling, apple
# 4   1102782                         Apples, baby food, toddler
# ..      ...                                                ...
# 95  1103288                   Tomato and vegetable juice, 100%
# 96  1103813  Vegetable and fruit juice, 100% juice, with hi...
# 97  1100865                             Muffin, fruit, low fat
# 98  1103343                                  Cabbage, red, raw
# 99  1104487                                                Gin
#
#                             category  energy  protein   carb    fat  \
# 0                             Apples    52.0     0.26  13.81   0.17
# 1   Doughnuts, sweet rolls, pastries   381.0     6.46  34.75  24.46
# 2                             Apples   112.0     0.32  22.70   3.04
# 3                     Cakes and pies   348.0     3.64  43.55  18.08
# 4                   Baby food: fruit    50.0     0.19  11.56   0.36
# ..                               ...     ...      ...    ...    ...
# 95                   Vegetable juice    22.0     0.93   3.87   0.31
# 96                 Other fruit juice    46.0     0.30  11.15   0.01
# 97   Biscuits, muffins, quick breads   255.0     4.23  50.05   4.22
# 98                           Cabbage    31.0     1.43   7.37   0.16
# 99              Liquor and cocktails   231.0     0.00   0.00   0.00
#
#                                                  clip     score  \
# 0   [0.03289434, 0.009451146, 0.04302109, -0.00526...  0.274602
# 1   [0.057608202, 0.031312082, 0.02672885, -0.0110...  0.258467
# 2   [0.02772038, -0.01954301, 0.027409052, -0.0049...  0.255700
# 3   [0.047357026, 0.0405507, -0.015996952, -0.0136...  0.246986
# 4   [0.0003478544, -0.022820584, 0.033641424, 0.00...  0.245114
# ..                                                ...       ...
# 95  [0.03134079, 0.023050051, 0.0139320195, 0.0197...  0.200651
# 96  [0.011157938, 0.048245464, 0.0036253047, 0.057...  0.200449
# 97  [0.0011837828, 0.00715228, 0.029665468, -0.004...  0.200284
# 98  [0.067335136, 0.014064836, -0.0027001977, -0.0...  0.199914
# 99  [0.0077090804, -0.0048638433, 0.041360896, -0....  0.199616
#
#                                   altered_description
# 0   I am going to eat some  raw Apple which blongs...
# 1   I am going to eat some  apple Fritter which bl...
# 2   I am going to eat some  baked Apple which blon...
# 3   I am going to eat some  apple Turnover or dump...
# 4   I am going to eat some  toddler  baby food App...
# ..                                                ...
# 95  I am going to eat some  100% Tomato and vegeta...
# 96  I am going to eat some  with high vitamin C  1...
# 97  I am going to eat some  low fat  fruit Muffin ...
# 98  I am going to eat some  raw  red Cabbage which...
# 99  I am going to eat some Gin which blongs to Liq...
#
# [100 rows x 10 columns]

# %%
clip = []
for i in selected.index:
    text = selected.loc[i,'altered_description']
    clip.append(requests.post(f'https://guru.skynet.center/text2vector/?text={text}').json())
selected['clip'] = clip

# %%
selected = selected.reset_index(drop=True)
clip = series2tensor(selected['clip'])
initscore = cos(image_clip.reshape(1,768), clip.mean(0).reshape(1,768))

# %%
selected = selected.reset_index(drop=True)
for i in reversed(selected.index):
    clip = series2tensor(selected['clip'])
    T = torch.cat([clip, clip[i].reshape(1,768)])
    testscore = cos(image_clip.reshape(1,768), T.mean(0).reshape(1,768))
    if testscore > initscore: 
        selected = selected.append(selected.loc[i])
        
        # print(f"added {selected.loc[i,'description']}")
        initscore = testscore
    else:

        T = torch.cat([clip[0:i], clip[i+1:]])
        testscore = cos(image_clip.reshape(1,768), T.mean(0).reshape(1,768))
        if testscore > initscore: 
            r = selected.loc[i,'altered_description']
            selected = selected.drop(i)
            initscore = testscore
            # print(f"removed {r}")




print(initscore)
count = selected.groupby('altered_description')['clip'].count().sort_index()
r = selected.drop_duplicates('altered_description').set_index("altered_description").sort_index()
r['count'] = count
r = r.sort_values('count',ascending = False)
r['cumcount'] = r['count'].cumsum()/r['count'].sum()
r
# Out:
# tensor([0.2690], dtype=torch.float64)
#                                                          id  \
# altered_description
# I am going to eat some  raw Apple which blongs ...  1102644
# I am going to eat some  junior  baby food Dutch...  1102867
# I am going to eat some  with calcium added  100...  1102748
# I am going to eat some  candied Apple which blo...  1102721
# I am going to eat some Cereal (General Mills Ch...  1101693
# I am going to eat some  raw Nectarine which blo...  1102673
#
#                                                                                        description  \
# altered_description
# I am going to eat some  raw Apple which blongs ...                                      Apple, raw
# I am going to eat some  junior  baby food Dutch...          Dutch apple dessert, baby food, junior
# I am going to eat some  with calcium added  100...           Apple juice, 100%, with calcium added
# I am going to eat some  candied Apple which blo...                                  Apple, candied
# I am going to eat some Cereal (General Mills Ch...  Cereal (General Mills Cheerios Apple Cinnamon)
# I am going to eat some  raw Nectarine which blo...                                  Nectarine, raw
#
#                                                                                            category  \
# altered_description
# I am going to eat some  raw Apple which blongs ...                                           Apples
# I am going to eat some  junior  baby food Dutch...                     Baby food: snacks and sweets
# I am going to eat some  with calcium added  100...                                      Apple juice
# I am going to eat some  candied Apple which blo...                                           Apples
# I am going to eat some Cereal (General Mills Ch...  Ready-to-eat cereal, higher sugar (>21.2g/100g)
# I am going to eat some  raw Nectarine which blo...                           Peaches and nectarines
#
#                                                     energy  protein   carb  \
# altered_description
# I am going to eat some  raw Apple which blongs ...    52.0     0.26  13.81
# I am going to eat some  junior  baby food Dutch...    79.0     0.20  19.18
# I am going to eat some  with calcium added  100...    48.0     0.12  11.49
# I am going to eat some  candied Apple which blo...   134.0     1.34  29.61
# I am going to eat some Cereal (General Mills Ch...   386.0     8.30  79.90
# I am going to eat some  raw Nectarine which blo...    39.0     1.06   9.18
#
#                                                      fat  \
# altered_description
# I am going to eat some  raw Apple which blongs ...  0.17
# I am going to eat some  junior  baby food Dutch...  0.16
# I am going to eat some  with calcium added  100...  0.17
# I am going to eat some  candied Apple which blo...  2.15
# I am going to eat some Cereal (General Mills Ch...  6.09
# I am going to eat some  raw Nectarine which blo...  0.28
#
#                                                                                                  clip  \
# altered_description
# I am going to eat some  raw Apple which blongs ...  [0.025421161204576492, 0.036097947508096695, 0...
# I am going to eat some  junior  baby food Dutch...  [0.008863253518939018, -0.016027363017201424, ...
# I am going to eat some  with calcium added  100...  [0.014394859783351421, -0.009781846776604652, ...
# I am going to eat some  candied Apple which blo...  [0.03971079736948013, 0.0382964052259922, 0.01...
# I am going to eat some Cereal (General Mills Ch...  [0.06687919795513153, 0.026330869644880295, -0...
# I am going to eat some  raw Nectarine which blo...  [0.04510404169559479, 0.031627148389816284, 0....
#
#                                                        score  count  cumcount
# altered_description
# I am going to eat some  raw Apple which blongs ...  0.274602     16  0.551724
# I am going to eat some  junior  baby food Dutch...  0.209188      4  0.689655
# I am going to eat some  with calcium added  100...  0.230542      4  0.827586
# I am going to eat some  candied Apple which blo...  0.240039      2  0.896552
# I am going to eat some Cereal (General Mills Ch...  0.221832      2  0.965517
# I am going to eat some  raw Nectarine which blo...  0.230622      1  1.000000

# %%
selected['energy'].mean()
# Out:
# 83.41379310344827

# %%
read_image_from_url(url)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x220 at 0x7F2624500EE0>

# %%
selected['energy'].mean()
# Out:
# 185.0
