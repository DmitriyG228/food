# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from food.tools import *
from food.paths import *
from food.psql import *

import pandas as pd
import numpy as np

# !nbdev_build_lib

# %%
from transformers import DetrFeatureExtractor, DetrForSegmentation
from PIL import Image
import requests

url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQywktoozOyUyYCcMJDpjSMqcwzeR_m23X67A&usqp=CAU'
image = Image.open(requests.get(url, stream=True).raw)

feature_extractor = DetrFeatureExtractor.from_pretrained('facebook/detr-resnet-50-panoptic')
model = DetrForSegmentation.from_pretrained('facebook/detr-resnet-50-panoptic')

inputs = feature_extractor(images=image, return_tensors="pt")
outputs = model(**inputs)
# model predicts COCO classes, bounding boxes, and masks
logits = outputs.logits
bboxes = outputs.pred_boxes
masks = outputs.pred_masks

# %%
from transformers import BeitFeatureExtractor, BeitForSemanticSegmentation
from PIL import Image

feature_extractor = BeitFeatureExtractor.from_pretrained('microsoft/beit-base-finetuned-ade-640-640')
model = BeitForSemanticSegmentation.from_pretrained('microsoft/beit-base-finetuned-ade-640-640')

# %%
from transformers import SegformerFeatureExtractor, SegformerForSemanticSegmentation
from PIL import Image
import requests

feature_extractor = SegformerFeatureExtractor.from_pretrained("nvidia/segformer-b4-finetuned-ade-512-512")
model = SegformerForSemanticSegmentation.from_pretrained("nvidia/segformer-b4-finetuned-ade-512-512")
# Out:
# Downloading:   0%|          | 0.00/271 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.72k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/245M [00:00<?, ?B/s]

# %%
from transformers import pipeline
pipe = pipeline("image-segmentation", device=2,model=model,feature_extractor=feature_extractor)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F02CC7890D0>

# %%
r = pipe([image])

# %%
pd.DataFrame(r[0])
# Out:
#   score      label                                               mask
# 0  None       wall  <PIL.Image.Image image mode=L size=275x183 at ...
# 1  None      floor  <PIL.Image.Image image mode=L size=275x183 at ...
# 2  None      table  <PIL.Image.Image image mode=L size=275x183 at ...
# 3  None   painting  <PIL.Image.Image image mode=L size=275x183 at ...
# 4  None  signboard  <PIL.Image.Image image mode=L size=275x183 at ...
# 5  None       food  <PIL.Image.Image image mode=L size=275x183 at ...
# 6  None       tray  <PIL.Image.Image image mode=L size=275x183 at ...
# 7  None      plate  <PIL.Image.Image image mode=L size=275x183 at ...
# 8  None      glass  <PIL.Image.Image image mode=L size=275x183 at ...

# %%
r[0][1]['mask']
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F02CC76BE20>

# %%
bboxes.shape
# Out:
# torch.Size([1, 100, 4])

# %%
bboxes[:,:,4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/dima/food/0_template copy 2.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bml2/home/dima/food/0_template%20copy%202.ipynb#ch0000017vscode-remote?line=0'>1</a> bboxes[:,:,4]
#
# IndexError: index 4 is out of bounds for dimension 2 with size 4

# %%
bboxes[0,:,:]
# Out:
# tensor([[0.6515, 0.2453, 0.5809, 0.3579],
#         [0.4439, 0.1619, 0.0713, 0.1149],
#         [0.7144, 0.7493, 0.1403, 0.1429],
#         [0.4614, 0.2074, 0.4625, 0.3641],
#         [0.7646, 0.5778, 0.1335, 0.3114],
#         [0.1091, 0.0202, 0.2137, 0.0399],
#         [0.5333, 0.5977, 0.1901, 0.2553],
#         [0.4046, 0.1744, 0.0790, 0.1287],
#         [0.0291, 0.9641, 0.0554, 0.0675],
#         [0.2743, 0.2918, 0.0863, 0.1068],
#         [0.6983, 0.5103, 0.1590, 0.2581],
#         [0.5000, 0.4990, 0.9983, 0.9982],
#         [0.5255, 0.3601, 0.2639, 0.1531],
#         [0.2865, 0.2483, 0.0722, 0.1693],
#         [0.8409, 0.6771, 0.1010, 0.1429],
#         [0.0846, 0.9602, 0.1654, 0.0758],
#         [0.6253, 0.5028, 0.5701, 0.9061],
#         [0.4243, 0.4991, 0.7670, 0.9621],
#         [0.6549, 0.4793, 0.5155, 0.7025],
#         [0.7640, 0.7394, 0.2822, 0.2656],
#         [0.6682, 0.5217, 0.1931, 0.3140],
#         [0.3939, 0.1647, 0.0549, 0.1063],
#         [0.5262, 0.3270, 0.2747, 0.1321],
#         [0.1839, 0.5147, 0.3649, 0.9514],
#         [0.8768, 0.6832, 0.0593, 0.1262],
#         [0.2998, 0.1919, 0.1658, 0.3237],
#         [0.4622, 0.2833, 0.1539, 0.0459],
#         [0.4105, 0.1658, 0.0877, 0.1471],
#         [0.9434, 0.5723, 0.0676, 0.1661],
#         [0.4385, 0.3271, 0.1234, 0.1051],
#         [0.7163, 0.5843, 0.2003, 0.3920],
#         [0.6636, 0.3964, 0.0730, 0.0799],
#         [0.5742, 0.2305, 0.7185, 0.3667],
#         [0.5004, 0.0229, 0.9978, 0.0453],
#         [0.1086, 0.2110, 0.2144, 0.2636],
#         [0.6581, 0.1801, 0.0762, 0.1027],
#         [0.4848, 0.4983, 0.8968, 0.9738],
#         [0.8880, 0.5282, 0.1796, 0.2613],
#         [0.3453, 0.7092, 0.2078, 0.1960],
#         [0.7835, 0.4461, 0.3516, 0.5929],
#         [0.8807, 0.3035, 0.1415, 0.1554],
#         [0.5803, 0.8557, 0.2189, 0.2431],
#         [0.6746, 0.6793, 0.0597, 0.0953],
#         [0.2962, 0.1976, 0.1323, 0.3057],
#         [0.7699, 0.2861, 0.3311, 0.3015],
#         [0.4972, 0.6515, 0.8215, 0.6444],
#         [0.8049, 0.4606, 0.0752, 0.0943],
#         [0.6890, 0.5725, 0.0742, 0.0402],
#         [0.5712, 0.4141, 0.1436, 0.1034],
#         [0.6874, 0.1833, 0.0566, 0.0735],
#         [0.0641, 0.2274, 0.1268, 0.2151],
#         [0.5222, 0.7905, 0.1622, 0.1865],
#         [0.7963, 0.2310, 0.2272, 0.1417],
#         [0.7808, 0.5808, 0.1084, 0.3023],
#         [0.5917, 0.4453, 0.3829, 0.3382],
#         [0.3032, 0.1964, 0.1460, 0.3134],
#         [0.8703, 0.6024, 0.0811, 0.0707],
#         [0.6704, 0.3992, 0.0874, 0.0910],
#         [0.7031, 0.7475, 0.1664, 0.2071],
#         [0.4999, 0.4966, 0.9971, 0.9866],
#         [0.1324, 0.2091, 0.2619, 0.3345],
#         [0.5309, 0.3079, 0.2658, 0.0828],
#         [0.4731, 0.3674, 0.9335, 0.7015],
#         [0.8627, 0.6861, 0.0923, 0.1379],
#         [0.6640, 0.4071, 0.5490, 0.6423],
#         [0.5378, 0.6235, 0.2053, 0.3050],
#         [0.6774, 0.1843, 0.0610, 0.0796],
#         [0.4741, 0.7109, 0.5089, 0.5128],
#         [0.7099, 0.7156, 0.1507, 0.2149],
#         [0.6785, 0.8404, 0.4059, 0.2714],
#         [0.3582, 0.5204, 0.2532, 0.2717],
#         [0.8581, 0.6133, 0.1229, 0.2784],
#         [0.1197, 0.5681, 0.2365, 0.4244],
#         [0.5623, 0.5865, 0.2465, 0.3591],
#         [0.4786, 0.5006, 0.4597, 0.9461],
#         [0.5855, 0.3860, 0.7154, 0.7171],
#         [0.6963, 0.4696, 0.1913, 0.2150],
#         [0.5733, 0.7218, 0.2688, 0.4914],
#         [0.4999, 0.4952, 0.9968, 0.9839],
#         [0.8786, 0.5300, 0.1604, 0.2230],
#         [0.5905, 0.8461, 0.2357, 0.2491],
#         [0.8096, 0.2900, 0.2674, 0.2532],
#         [0.4928, 0.5419, 0.9113, 0.8674],
#         [0.0912, 0.6827, 0.1819, 0.6229],
#         [0.4661, 0.7560, 0.8727, 0.4398],
#         [0.8576, 0.6112, 0.1109, 0.1416],
#         [0.5196, 0.8259, 0.1358, 0.1702],
#         [0.6457, 0.3968, 0.0643, 0.0779],
#         [0.8076, 0.5888, 0.0923, 0.2953],
#         [0.6442, 0.2102, 0.1043, 0.2181],
#         [0.2997, 0.2293, 0.1735, 0.3635],
#         [0.0333, 0.9510, 0.0651, 0.0932],
#         [0.3448, 0.5860, 0.2974, 0.4136],
#         [0.7133, 0.8017, 0.1527, 0.1372],
#         [0.8608, 0.6505, 0.1017, 0.1569],
#         [0.7371, 0.6970, 0.1938, 0.1973],
#         [0.0498, 0.9638, 0.0978, 0.0687],
#         [0.8028, 0.2898, 0.2353, 0.2031],
#         [0.8923, 0.5943, 0.1241, 0.1580],
#         [0.4559, 0.1481, 0.2289, 0.2475]], grad_fn=<SliceBackward0>)
