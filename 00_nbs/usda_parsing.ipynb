# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0,'..')

# %%
from food.tools import *
from food.paths import *
from food.psql import *

import pandas as pd
import numpy as np

# !nbdev_build_lib
from pathlib import Path

# %%
data_path = Path('../food_dataset')

# %%
n=9

# %%
df = pd.read_csv('../food_dataset/measure_unit.csv')

# %%
df
# Out:
#        id          name
# 0    1000           cup
# 1    1001    tablespoon
# 2    1002      teaspoon
# 3    1003         liter
# 4    1004    milliliter
# ..    ...           ...
# 117  1117         bunch
# 118  1118   Tablespoons
# 119  1119        Banana
# 120  1120         Onion
# 121  9999  undetermined
#
# [122 rows x 2 columns]

# %%
n+=1
p = data_path.ls()[n]
print(p)
pd.read_csv(p)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [147], in <cell line: 2>()
#       1 n+=1
# ----> 2 p = data_path.ls()[n]
#       3 print(p)
#       4 pd.read_csv(p)
#
# IndexError: list index out of range

# %%
data_path.ls()
# Out:
# [PosixPath('../food_dataset/branded_food.csv'),
#  PosixPath('../food_dataset/lab_method.csv'),
#  PosixPath('../food_dataset/food_calorie_conversion_factor.csv'),
#  PosixPath('../food_dataset/agricultural_samples.csv'),
#  PosixPath('../food_dataset/sr_legacy_food.csv'),
#  PosixPath('../food_dataset/food_attribute.csv'),
#  PosixPath('../food_dataset/food_nutrient_derivation.csv'),
#  PosixPath('../food_dataset/acquisition_samples.csv'),
#  PosixPath('../food_dataset/all_downloaded_table_record_counts.csv'),
#  PosixPath('../food_dataset/food_nutrient_source.csv'),
#  PosixPath('../food_dataset/food_attribute_type.csv'),
#  PosixPath('../food_dataset/food_component.csv'),
#  PosixPath('../food_dataset/food_protein_conversion_factor.csv'),
#  PosixPath('../food_dataset/foundation_food.csv'),
#  PosixPath('../food_dataset/Download & API Field Descriptions October 2022.pdf'),
#  PosixPath('../food_dataset/food_update_log_entry.csv'),
# ...

# %%
df = pd.read_csv(data_path/'food.csv')

# %%
df['data_type'].unique()
# Out:
# array(['branded_food', 'experimental_food', 'sr_legacy_food',
#        'sample_food', 'market_acquistion', 'sub_sample_food',
#        'foundation_food', 'agricultural_acquisition', 'survey_fndds_food'],
#       dtype=object)

# %%
df[df['data_type']=='survey_fndds_food']
# Out:
#          fdc_id          data_type                               description  \
# 559101  1097510  survey_fndds_food                               Milk, human
# 559102  1097511  survey_fndds_food                                 Milk, NFS
# 559103  1097512  survey_fndds_food                               Milk, whole
# 559104  1097513  survey_fndds_food                   Milk, low sodium, whole
# 559105  1097514  survey_fndds_food            Milk, calcium fortified, whole
# ...         ...                ...                                       ...
# 566179  1104588  survey_fndds_food          Tomatoes as ingredient in omelet
# 566180  1104589  survey_fndds_food  Other vegetables as ingredient in omelet
# 566181  1104590  survey_fndds_food         Vegetables as ingredient in curry
# 566182  1104591  survey_fndds_food         Sauce as ingredient in hamburgers
# 566183  1104592  survey_fndds_food      Industrial oil as ingredient in food
#
#         food_category_id publication_date
# ...

# %%
foundation_food = df[df['data_type']=='foundation_food'].drop_duplicates('description')[['fdc_id','description']]

# %%
foundation_food.rename(columns = {'fdc_id':'id'}).to_sql('foundation_foods',schema = 'food',con = engine,if_exists = 'append',index = False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/anaconda3/envs/stego/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~/anaconda3/envs/stego/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
# ...

# %%
foundation_food

# %%
pd.read_csv(data_path/'food_nutrient.csv')
# Out:
# /tmp/ipykernel_1294208/4146138371.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(data_path/'food_nutrient.csv')
#                id   fdc_id  nutrient_id   amount  data_points  derivation_id  \
# 0        13694818  1106281          203   10.710          NaN           70.0
# 1        13694819  1106281          204   25.000          NaN           70.0
# 2        13694826  1106281          307  161.000          NaN           70.0
# 3        13694824  1106281          301   71.000          NaN           75.0
# 4        13694829  1106281          601    0.000          NaN           75.0
# ...           ...      ...          ...      ...          ...            ...
# 5917365  27797216  2263892         1014    0.000          8.0            1.0
# 5917366  27797202  2263892         1039  425.900          8.0            1.0
# 5917367  27797205  2263892         1044    5.413          8.0            1.0
# ...

# %%
path_info(data_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 path_info(data_path)
#
# NameError: name 'path_info' is not defined

# %%
fundation_path = data_path/'FoundationFoods'
fndds_path = data_path/'FNDDS'
support_path = data_path/'support_data'
branded_path = data_path/'branded'
full_path = data_path/'full'

# %%
pd.read_csv(data_path/'foundation_food.csv')
# Out:
#       fdc_id  NDB_number                             footnote
# 0     321358       16158                                  NaN
# 1     321360      100147                                  NaN
# 2     321611       11056                                  NaN
# 3     323121        7022                                  NaN
# 4     323294       12563   Other phytosterols = 34.67 mg/100g
# ..       ...         ...                                  ...
# 179  2263888        9302                                  NaN
# 180  2263889        9050                                  NaN
# 181  2263890      100279                                  NaN
# 182  2263891      100280                                  NaN
# 183  2263892        9401                                  NaN
#
# [184 rows x 3 columns]

# %%
nutrients = pd.read_csv(data_path/'nutrient.csv').sort_values('id');nutrients
# Out:
#        id                                        name unit_name  nutrient_nbr  \
# 2    1001                                      Solids         G         201.0
# 3    1002                                    Nitrogen         G         202.0
# 4    1003                                     Protein         G         203.0
# 5    1004                           Total lipid (fat)         G         204.0
# 6    1005                 Carbohydrate, by difference         G         205.0
# ..    ...                                         ...       ...           ...
# 469  2061                         Ergosta-7,22-dienol        MG           NaN
# 470  2062                          Ergosta-5,7-dienol        MG           NaN
# 471  2063                                  Verbascose         G           NaN
# 472  2064                           Oligiosaccharides        MG           NaN
# 473  2065  Low Molecular Weight Dietary Fiber (LMWDF)         G         293.4
#
#         rank
# 2      200.0
# ...

# %%
measures = pd.read_csv(data_path/'measure_unit.csv').sort_values('id');measures
# Out:
#        id          name
# 0    1000           cup
# 1    1001    tablespoon
# 2    1002      teaspoon
# 3    1003         liter
# 4    1004    milliliter
# ..    ...           ...
# 117  1117         bunch
# 118  1118   Tablespoons
# 119  1119        Banana
# 120  1120         Onion
# 121  9999  undetermined
#
# [122 rows x 2 columns]

# %%
fndds = pd.read_csv(data_path/'food_update_log_entry.csv').sort_values('id')
fndds_nutrients = pd.read_csv(data_path/'food_nutrient.csv').sort_values('id')
fndd_portions = pd.read_csv(data_path/'food_portion.csv').sort_values('id')
attributes = pd.read_csv(data_path/'food_attribute.csv')
# Out:
# /tmp/ipykernel_1294208/3483475768.py:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   fndds_nutrients = pd.read_csv(data_path/'food_nutrient.csv').sort_values('id')
# /tmp/ipykernel_1294208/3483475768.py:4: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   attributes = pd.read_csv(data_path/'food_attribute.csv')

# %%
fndd_portions.groupby('modifier').count().sort_values('id')
# Out:
#                        id  fdc_id  seq_num  amount  measure_unit_id  \
# modifier
# oz shelled              1       1        1       1                1
# 63895                   1       1        1       0                1
# 63894                   1       1        1       0                1
# 63893                   1       1        1       0                1
# 63892                   1       1        1       0                1
# ...                   ...     ...      ...     ...              ...
# whole without shell  1607    1607        1    1607             1607
# cup                  1691    1691     1691    1691             1691
# oz                   3166    3166     3166    3166             3166
# 10205                3305    3305     3305       0             3305
# 90000                7056    7056     7056       0             7056
#
#                      portion_description  gram_weight  data_points  footnote  \
# modifier
# ...

# %%
ozs = fndd_portions[fndd_portions['modifier']=='oz']

# %%
(ozs['gram_weight']/ozs['amount']).describe()
# Out:
# count    3166.000000
# mean       28.341087
# std         0.672798
# min        28.000000
# 25%        28.333333
# 50%        28.333333
# 75%        28.350000
# max        64.000000
# dtype: float64

# %%
fndd_portions
# Out:
#            id   fdc_id  seq_num  amount  measure_unit_id portion_description  \
# 0       81549   167512      1.0     1.0             9999                 NaN
# 1       81550   167513      1.0     1.0             9999                 NaN
# 2       81551   167514      1.0     1.0             9999                 NaN
# 3       81552   167515      1.0     1.0             9999                 NaN
# 4       81553   167516      1.0     1.0             9999                 NaN
# ...       ...      ...      ...     ...              ...                 ...
# 56888  267791  1105295      NaN     1.0             1119                 NaN
# 56889  267792  1105295      NaN     1.0             1119                 NaN
# 56890  267793  1105295      NaN     1.0             1119                 NaN
# 56891  267794  1105295      NaN     1.0             1119                 NaN
# 56892  267795  1105314      1.0     1.0             1119                 NaN
#
# ...

# %%
fndd_portions[fndd_portions['fdc_id']==173429]
# Out:
#           id  fdc_id  seq_num  amount  measure_unit_id portion_description  \
# 10960  92509  173429      1.0    0.35             9999                 NaN
# 10961  92510  173429      2.0    0.70             9999                 NaN
#
#       modifier  gram_weight  data_points  footnote  min_year_acquired
# 10960       oz          9.9          NaN       NaN                NaN
# 10961       oz         20.0          NaN       NaN                NaN

# %%
9.9/0.35
# Out:
# 28.28571428571429

# %%
df = df.dropna(subset = ['description'])

# %%
df[df['fdc_id']==173429]
# Out:
#        fdc_id       data_type             description  food_category_id  \
# 39800  173429  sr_legacy_food  Egg substitute, powder               NaN
#
#       publication_date
# 39800       2019-04-01

# %%
fndd_portions['modifier'].unique().tolist()
# Out:
# ['serving',
#  'serving 1 roll with icing',
#  'waffle, square',
#  'waffle, round',
#  'oz',
#  'waffle round (4" dia)',
#  'waffle',
#  'waffle, round (4"dia)',
#  'crust',
#  'pie 1 pie (1/8 of 9" pie)',
#  'slice',
#  'pie',
#  'pie crust (average weight)',
#  'waffles',
#  'piece',
#  'pieces (mean serving weight, aggregated over brands)',
#  'serving (approximate serving size)',
#  'cake square (average weight of whole item)',
#  'cake square',
#  'serving (1 NLEA serving - about 4 crackers)',
#  'cracker',
#  'crackers (1 NLEA serving)',
#  'bagel',
#  'tortilla',
#  'package',
#  'piece, large',
#  'bag (7 oz)',
#  'packet (.75 oz)',
#  'large',
#  'small',
#  'bar',
#  'bar (1 oz)',
#  'bar (1.5 oz)',
#  'bar (1.25 oz)',
#  'cup',
#  'cake',
#  'cakes',
#  'oz (approx 2/3 cup)',
#  'can (6 oz)',
#  'can (6.75 oz)',
#  'twists',
#  'pretzel',
#  'bag',
#  'package 1.76 oz',
#  'bar snack size',
#  'pieces',
#  'serving 6 pieces',
#  'serving 2.1 oz bar',
# ...

# %%
fndd_portions.groupby('modifier')['id'].count().sort_values().tail(20)
# Out:
# modifier
# without skin            346
# with skin               346
# 10049                   349
# 40081                   386
# 40072                   386
# 40029                   400
# 51005                   422
# 40018                   430
# 21000                   447
# fl oz                   492
# tbsp                    548
# 30000                   654
# yolk                   1457
# white                  1484
# whole in shell         1581
# whole without shell    1607
# cup                    1691
# oz                     3166
# 10205                  3305
# 90000                  7056
# Name: id, dtype: int64

# %%
fndds_nutrients = (
    fndds[['id','description']].set_index('id').join(fndds_nutrients[['fdc_id','nutrient_id','amount']].set_index('fdc_id'))
    .reset_index()
    .set_index('nutrient_id')
    .join(nutrients.set_index('id'))
    .rename(columns = {'index':'id'})

)

# %%
fndds_nutrients = fndds_nutrients.pivot(index = ['id','description'],columns = ['name'],values = ['amount'])
fndds_nutrients.columns = fndds_nutrients.columns.get_level_values(1)
fndds_nutrients.columns = fndds_nutrients.columns.str.lower()


fndds_nutrients = fndds_nutrients[['energy',
                                    'protein',
                                    'carbohydrate, by difference',
                                    'total lipid (fat)']]
fndds_nutrients = fndds_nutrients.rename(columns = {'carbohydrate, by difference':'carb','total lipid (fat)':'fat'}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 9>()
#       1 fndds_nutrients = (
#       2     fndds[['id','description']].set_index('id').join(fndds_nutrients[['fdc_id','nutrient_id','amount']].set_index('fdc_id'))
#       3     .reset_index()
#    (...)
#       7
#       8 )
# ----> 9 fndds_nutrients = fndds_nutrients.pivot(index = ['id','description'],columns = ['name'],values = ['amount'])
#      10 fndds_nutrients.columns = fndds_nutrients.columns.get_level_values(1)
#      11 fndds_nutrients.columns = fndds_nutrients.columns.str.lower()
#
# File ~/anaconda3/envs/stego/lib/python3.9/site-packages/pandas/core/frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    7871 @Substitution("")
#    7872 @Appender(_shared_docs["pivot"])
#    7873 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
# ...

# %%
attributes = attributes[attributes['name'] == 'WWEIA Category description'][['fdc_id','value']].rename(columns = {'fdc_id':'id','value':'category'})

# %%
fndds_nutrients = fndds_nutrients.merge(attributes,on='id')

# %%
foods = pd.read_sql('select id, description from foods',engine)

# %%
foods

# %%
fndd_portions[['fdc_id','portion_description','gram_weight']].rename(columns = {'fdc_id':"food_id"}).to_sql('portions',engine,if_exists='append',index=False)

# %%
fndd_portions[fndd_portions['fdc_id']==1101970]
# Out:
#            id   fdc_id  seq_num  amount  measure_unit_id  \
# 21515  246068  1101970       11     NaN             9999
# 21514  253926  1101970        1     NaN             9999
# 21513  256883  1101970        6     NaN             9999
# 21510  256955  1101970        7     NaN             9999
# 21509  257015  1101970        8     NaN             9999
# 21507  257078  1101970        9     NaN             9999
# 21506  257141  1101970       10     NaN             9999
# 21512  257201  1101970        2     NaN             9999
# 21511  257261  1101970        3     NaN             9999
# 21508  257324  1101970        4     NaN             9999
# 21505  257693  1101970        5     NaN             9999
# 21504  264731  1101970       12     NaN             9999
#
#                          portion_description  modifier  gram_weight  \
# 21515                         1 surface inch     52000          6.2
# 21514                           1 piece, NFS     63542        119.0
# ...

# %%
portions = fndds_nutrients.set_index('id').join(fndd_portions[['fdc_id','portion_description','gram_weight']].set_index('fdc_id'))

# %%
portions['portion_description'].drop_duplicates()
# Out:
# 1097510                                     1 cup
# 1097510                                   1 fl oz
# 1097510                    Quantity not specified
# 1097511    Guideline amount per fl oz of beverage
# 1097511    Guideline amount per cup of hot cereal
#                             ...
# 1104546                1 can or bottle (24 fl oz)
# 1104546                1 can or bottle (32 fl oz)
# 1104559                       1 bottle (32 fl oz)
# 1104566                           1 bottle (4 oz)
# 1104568                                       NaN
# Name: portion_description, Length: 1855, dtype: object

# %%
portions[portions['description'].str.contains('Apple, raw')]
# Out:
#         description  energy  protein   carb   fat category  \
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
# 1102644  Apple, raw    52.0     0.26  13.81  0.17   Apples
#
#               portion_description  gram_weight
# 1102644                     1 cup        125.0
# 1102644             1 extra large        295.0
# 1102644                   1 large        242.0
# 1102644                  1 medium        200.0
# 1102644                   1 slice         25.0
# 1102644                   1 small        165.0
# 1102644  1 single serving package         34.0
# 1102644    Quantity not specified        200.0

# %%
portions['portion_description'].str.split(' ').str[:2]
# Out:
# 1097510           [1, cup]
# 1097510            [1, fl]
# 1097510    [Quantity, not]
# 1097511           [1, cup]
# 1097511            [1, fl]
#                 ...
# 1104588                NaN
# 1104589                NaN
# 1104590                NaN
# 1104591                NaN
# 1104592                NaN
# Name: portion_description, Length: 31791, dtype: object

# %%
portions
# Out:
#                                       description  energy  protein   carb  \
# 1097510                               Milk, human    70.0     1.03   6.89
# 1097510                               Milk, human    70.0     1.03   6.89
# 1097510                               Milk, human    70.0     1.03   6.89
# 1097511                                 Milk, NFS    51.0     3.34   4.87
# 1097511                                 Milk, NFS    51.0     3.34   4.87
# ...                                           ...     ...      ...    ...
# 1104588          Tomatoes as ingredient in omelet    25.0     1.11   5.48
# 1104589  Other vegetables as ingredient in omelet    29.0     3.46   4.81
# 1104590         Vegetables as ingredient in curry    52.0     1.81  11.60
# 1104591         Sauce as ingredient in hamburgers   271.0     1.34  17.14
# 1104592      Industrial oil as ingredient in food   892.0     0.00   0.00
#
#             fat                         category     portion_description  \
# ...

# %% [markdown]
# branded

# %%
food = pd.read_csv(branded_path/'food.csv')

# %%
branded_food = pd.read_csv(branded_path/'branded_food.csv')
# Out:
# /home/dima/anaconda3/envs/food/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (2,3,4,6,9,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
food = food[['description','fdc_id']].set_index('fdc_id')

# %%
branded_food = branded_food[['brand_name','ingredients','fdc_id','serving_size','serving_size_unit','package_weight']].set_index('fdc_id')

# %%
branded_food = food.join(branded_food)

# %%
branded_food
# Out:
#                                          description        brand_name  \
# fdc_id
# 1105904                   WESSON Vegetable Oil 1 GAL               NaN
# 1105905                           SWANSON BROTH BEEF               NaN
# 1105906     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER               NaN
# 1105907  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI               NaN
# 1105908                        SWANSON BROTH CHICKEN               NaN
# ...                                              ...               ...
# 2183200               Manuka Hunters Bush Honey 250g    Manuka Hunters
# 2183201               Manuka Hunters Bush Honey 500g    Manuka Hunters
# 2183202                Manuka Hunters Bush Honey 1kg    Manuka Hunters
# 2183203                       Rocket Fuel Sauce 300g       Rocket Fuel
# 2183204   The Kiwi Artisan Manuka Smoked Olives 150g  The Kiwi Artisan
#
#                                                ingredients  serving_size  \
# fdc_id
# ...

# %%
nutrients = pd.read_csv(branded_path/'food_nutrient.csv')

# %%
nutrients
# Out:
#                 id   fdc_id  nutrient_id  amount  data_points  derivation_id  \
# 0         13706913  1105904          203    0.00          NaN           71.0
# 1         13706914  1105904          204   93.33          NaN           71.0
# 2         13706915  1105904          205    0.00          NaN           75.0
# 3         13706924  1105904          324    0.00          NaN           75.0
# 4         13706918  1105904          291    0.00          NaN           75.0
# ...            ...      ...          ...     ...          ...            ...
# 19807009  26849607  2183204          291    3.20          NaN           71.0
# 19807010  26849609  2183204          606    3.80          NaN           71.0
# 19807011  26849602  2183204          203    1.20          NaN           71.0
# 19807012  26849606  2183204          269    0.20          NaN           71.0
# 19807013  26849603  2183204          204   31.60          NaN           71.0
#
# ...
